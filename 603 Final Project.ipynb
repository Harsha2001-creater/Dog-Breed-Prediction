# %% [markdown]
# ### Importing Spark Session

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# ### Creating Spark Session

# %%
spark = SparkSession.builder \
    .appName("MyProject") \
    .getOrCreate()

# %% [markdown]
# ### Initializing a SparkSession with configurations

# %%
spark = SparkSession.builder \
    .appName("CSVtoMongoDB") \
    .config("spark.mongodb.output.uri", "mongodb://localhost:27017/flights.cleaned") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1") \
    .config("spark.hadoop.fs.AbstractFileSystem.s3a.impl", "org.apache.hadoop.fs.LocalFileSystem") \
    .config("spark.sql.catalogImplementation", "in-memory") \
    .getOrCreate()

# %% [markdown]
# ### Reading Data using Spark

# %%
file_paths = {
    2009: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2009.csv",
    2010: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2010.csv",
    2011: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2011.csv",
    2012: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2012.csv",
    2013: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2013.csv",
    2014: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2014.csv",
    2015: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2015.csv",
    2016: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2016.csv",
    2017: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2017.csv",
    2018: "C:/Users/msrih/Downloads/UMBC CLASSES/603/Data Sets/2018.csv"
}

dfs = {}  # Dictionary to store DataFrames for each year

for year, file_path in file_paths.items():
    dfs[year] = spark.read.csv(file_path, header=True, inferSchema=True)

# %%
dfs[2009].show(1, vertical=True)
# Out:
# -RECORD 0-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1204
#  ORIGIN              | DCA
#  DEST                | EWR
#  CRS_DEP_TIME        | 1100
#  DEP_TIME            | 1058.0
#  DEP_DELAY           | -2.0
#  TAXI_OUT            | 18.0
#  WHEELS_OFF          | 1116.0
#  WHEELS_ON           | 1158.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 1202
#  ARR_TIME            | 1206.0
#  ARR_DELAY           | 4.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 62.0
#  ACTUAL_ELAPSED_TIME | 68.0
#  AIR_TIME            | 42.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# only showing top 1 row

# %% [markdown]
# ### Data Types

# %%
print("Data type of the loaded dataframes:")
for year, df in dfs.items():
    print(f'dfs[{year}]: {type(df)}')
# Out:
# Data type of the loaded dataframes:
# dfs[2009]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2010]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2011]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2012]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2013]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2014]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2015]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2016]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2017]: <class 'pyspark.sql.dataframe.DataFrame'>
# dfs[2018]: <class 'pyspark.sql.dataframe.DataFrame'>

# %% [markdown]
# ## Merging all datasets int to One

# %%
from functools import reduce
from pyspark.sql import DataFrame

# List comprehension to extract DataFrame values from the dictionary
dfs_list = [dfs[year] for year in dfs]

# Concatenating all DataFrames into a single DataFrame
df = reduce(DataFrame.unionAll, dfs_list)

# %% [markdown]
# ### Schema

# %%
#schema of df2008
df.printSchema()
# Out:
# root
#  |-- FL_DATE: date (nullable = true)
#  |-- OP_CARRIER: string (nullable = true)
#  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- DEST: string (nullable = true)
#  |-- CRS_DEP_TIME: double (nullable = true)
#  |-- DEP_TIME: double (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- TAXI_OUT: double (nullable = true)
#  |-- WHEELS_OFF: double (nullable = true)
#  |-- WHEELS_ON: double (nullable = true)
#  |-- TAXI_IN: double (nullable = true)
#  |-- CRS_ARR_TIME: double (nullable = true)
#  |-- ARR_TIME: double (nullable = true)
#  |-- ARR_DELAY: double (nullable = true)
#  |-- CANCELLED: double (nullable = true)
#  |-- CANCELLATION_CODE: string (nullable = true)
#  |-- DIVERTED: double (nullable = true)
#  |-- CRS_ELAPSED_TIME: double (nullable = true)
#  |-- ACTUAL_ELAPSED_TIME: double (nullable = true)
#  |-- AIR_TIME: double (nullable = true)
#  |-- DISTANCE: double (nullable = true)
#  |-- CARRIER_DELAY: double (nullable = true)
#  |-- WEATHER_DELAY: double (nullable = true)
#  |-- NAS_DELAY: double (nullable = true)
#  |-- SECURITY_DELAY: double (nullable = true)
#  |-- LATE_AIRCRAFT_DELAY: double (nullable = true)
#  |-- Unnamed: 27: string (nullable = true)

# %% [markdown]
# ## EDA on DataFrame

# %%
df.count()
# Out:
# 61556964

# %%
len(df.columns)
# Out:
# 28

# %%
df.columns
# Out:
# ['FL_DATE',
#  'OP_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN',
#  'DEST',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'Unnamed: 27']

# %%
df.describe().show()
# Out:
# +-------+----------+------------------+--------+--------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+-----------------+---------+------------------+-------------------+------------------+-----------------+
# |summary|OP_CARRIER| OP_CARRIER_FL_NUM|  ORIGIN|    DEST|      CRS_DEP_TIME|          DEP_TIME|        DEP_DELAY|          TAXI_OUT|        WHEELS_OFF|         WHEELS_ON|          TAXI_IN|      CRS_ARR_TIME|          ARR_TIME|        ARR_DELAY|CANCELLED|  CRS_ELAPSED_TIME|ACTUAL_ELAPSED_TIME|          AIR_TIME|         DISTANCE|
# +-------+----------+------------------+--------+--------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+-----------------+---------+------------------+-------------------+------------------+-----------------+
# |  count|  60431020|          60431020|60431020|60431020|          60431020|          60431020|         60431020|          60431020|          60431020|          60431020|         60431020|          60431020|          60431020|         60431020| 60431020|          60431020|           60431020|          60431020|         60431020|
# |   mean|      NULL|2289.5803571245365|    NULL|    NULL|  1326.49433180178| 1333.016772247101|8.983856949626201|15.984705503895185| 1355.937092605751|1473.6329105979016| 7.11399994572324| 1494.541719451368|1479.2377617653979|4.701129006262016|      0.0|137.16253448973723| 132.87984002255794|109.78113457293952| 788.773631836762|
# | stddev|      NULL|1882.5226466992592|    NULL|    NULL|474.78413254320174|487.48641875638793|36.97081379334839| 9.299156702748808|488.84439114976345| 511.1957287819116|5.287993926086464|495.65937645192395|  514.758481917568|39.43847943619039|      0.0| 73.48566312947595|  72.84298790132874| 70.68177099761523|594.6230835135307|
# |    min|        9E|                 0|     ABE|     ABE|               1.0|               1.0|           -234.0|               0.0|               1.0|               1.0|              0.0|               1.0|               1.0|           -411.0|      0.0|             -99.0|               11.0|               3.0|             11.0|
# |    max|        YX|              9320|     YUM|     YUM|            2359.0|            2400.0|           2710.0|             458.0|            2400.0|            2400.0|            414.0|            2400.0|            2400.0|           2692.0|      0.0|             718.0|              799.0|             723.0|           4983.0|
# +-------+----------+------------------+--------+--------+------------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+-----------------+---------+------------------+-------------------+------------------+-----------------+

# %%
#Check for duplicates
print("Number of duplicate rows:", df.count() - df.dropDuplicates().count())
# Out:
# Number of duplicate rows: 1024723

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Data Cleaning Process
#
# In this section, we'll outline the steps taken to clean the dataset:
#
# 1. **Checking for Null Values:** We begin by examining the dataset for any missing values. This step is crucial as missing data can affect the analysis and modeling process.
#
# 2. **Removing Unnecessary Columns:** Next, we identify and remove any unnecessary columns that do not contribute to our analysis or modeling goals. This helps streamline the dataset and improve efficiency.
#
# 3. **Removing Null Values:** After identifying missing values, we proceed to handle them appropriately. Depending on the context, we may choose to drop rows or impute missing values using statistical measures.
#
# 4. **Rechecking for Null Values:** Finally, we perform a final check to ensure that all missing values have been successfully addressed. Ideally, after cleaning, the dataset should be free from any null values, ensuring the integrity of our analysis.
#
# By following these steps, we ensure that our dataset is properly cleaned and prepared for further analysis or modeling tasks.

# %%
#To check the number of null values
from pyspark.sql.functions import col, isnan, unix_timestamp, when, count

uniondf2 = df.select([
    count(when(
        col(c).contains('None') | col(c).contains('NULL') | (col(c) == 'NA') | col(c).isNull() | isnan(c),
        c)
    ).alias(c) if c != 'FL_DATE' else
    count(when(
        col(c).contains('None') | col(c).contains('NULL') | (col(c) == 'NA') | col(c).isNull() | isnan(unix_timestamp(c)),
        c)
    ).alias(c)
    for c in df.columns
])

uniondf2.show(vertical=True)
# Out:
# -RECORD 0-----------------------
#  FL_DATE             | 0
#  OP_CARRIER          | 0
#  OP_CARRIER_FL_NUM   | 0
#  ORIGIN              | 0
#  DEST                | 0
#  CRS_DEP_TIME        | 1
#  DEP_TIME            | 935723
#  DEP_DELAY           | 940675
#  TAXI_OUT            | 963901
#  WHEELS_OFF          | 963896
#  WHEELS_ON           | 997016
#  TAXI_IN             | 997015
#  CRS_ARR_TIME        | 2
#  ARR_TIME            | 997015
#  ARR_DELAY           | 1121351
#  CANCELLED           | 0
#  CANCELLATION_CODE   | 60583755
#  DIVERTED            | 0
#  CRS_ELAPSED_TIME    | 60
#  ACTUAL_ELAPSED_TIME | 1118754
#  AIR_TIME            | 1118753
#  DISTANCE            | 0
#  CARRIER_DELAY       | 50166224
#  WEATHER_DELAY       | 50166224
#  NAS_DELAY           | 50166224
#  SECURITY_DELAY      | 50166224
#  LATE_AIRCRAFT_DELAY | 50166224
#  Unnamed: 27         | 61556964

# %%
df.printSchema()
# Out:
# root
#  |-- FL_DATE: date (nullable = true)
#  |-- OP_CARRIER: string (nullable = true)
#  |-- OP_CARRIER_FL_NUM: integer (nullable = true)
#  |-- ORIGIN: string (nullable = true)
#  |-- DEST: string (nullable = true)
#  |-- CRS_DEP_TIME: double (nullable = true)
#  |-- DEP_TIME: double (nullable = true)
#  |-- DEP_DELAY: double (nullable = true)
#  |-- TAXI_OUT: double (nullable = true)
#  |-- WHEELS_OFF: double (nullable = true)
#  |-- WHEELS_ON: double (nullable = true)
#  |-- TAXI_IN: double (nullable = true)
#  |-- CRS_ARR_TIME: double (nullable = true)
#  |-- ARR_TIME: double (nullable = true)
#  |-- ARR_DELAY: double (nullable = true)
#  |-- CANCELLED: double (nullable = true)
#  |-- CANCELLATION_CODE: string (nullable = true)
#  |-- DIVERTED: double (nullable = true)
#  |-- CRS_ELAPSED_TIME: double (nullable = true)
#  |-- ACTUAL_ELAPSED_TIME: double (nullable = true)
#  |-- AIR_TIME: double (nullable = true)
#  |-- DISTANCE: double (nullable = true)
#  |-- CARRIER_DELAY: double (nullable = true)
#  |-- WEATHER_DELAY: double (nullable = true)
#  |-- NAS_DELAY: double (nullable = true)
#  |-- SECURITY_DELAY: double (nullable = true)
#  |-- LATE_AIRCRAFT_DELAY: double (nullable = true)
#  |-- Unnamed: 27: string (nullable = true)

# %%
df.show(vertical=True)
# Out:
# -RECORD 0-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1204
#  ORIGIN              | DCA
#  DEST                | EWR
#  CRS_DEP_TIME        | 1100.0
#  DEP_TIME            | 1058.0
#  DEP_DELAY           | -2.0
#  TAXI_OUT            | 18.0
#  WHEELS_OFF          | 1116.0
#  WHEELS_ON           | 1158.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 1202.0
#  ARR_TIME            | 1206.0
#  ARR_DELAY           | 4.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 62.0
#  ACTUAL_ELAPSED_TIME | 68.0
#  AIR_TIME            | 42.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 1-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1206
#  ORIGIN              | EWR
#  DEST                | IAD
#  CRS_DEP_TIME        | 1510.0
#  DEP_TIME            | 1509.0
#  DEP_DELAY           | -1.0
#  TAXI_OUT            | 28.0
#  WHEELS_OFF          | 1537.0
#  WHEELS_ON           | 1620.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1632.0
#  ARR_TIME            | 1624.0
#  ARR_DELAY           | -8.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 82.0
#  ACTUAL_ELAPSED_TIME | 75.0
#  AIR_TIME            | 43.0
#  DISTANCE            | 213.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 2-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1207
#  ORIGIN              | EWR
#  DEST                | DCA
#  CRS_DEP_TIME        | 1100.0
#  DEP_TIME            | 1059.0
#  DEP_DELAY           | -1.0
#  TAXI_OUT            | 20.0
#  WHEELS_OFF          | 1119.0
#  WHEELS_ON           | 1155.0
#  TAXI_IN             | 6.0
#  CRS_ARR_TIME        | 1210.0
#  ARR_TIME            | 1201.0
#  ARR_DELAY           | -9.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 70.0
#  ACTUAL_ELAPSED_TIME | 62.0
#  AIR_TIME            | 36.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 3-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1208
#  ORIGIN              | DCA
#  DEST                | EWR
#  CRS_DEP_TIME        | 1240.0
#  DEP_TIME            | 1249.0
#  DEP_DELAY           | 9.0
#  TAXI_OUT            | 10.0
#  WHEELS_OFF          | 1259.0
#  WHEELS_ON           | 1336.0
#  TAXI_IN             | 9.0
#  CRS_ARR_TIME        | 1357.0
#  ARR_TIME            | 1345.0
#  ARR_DELAY           | -12.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 77.0
#  ACTUAL_ELAPSED_TIME | 56.0
#  AIR_TIME            | 37.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 4-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1209
#  ORIGIN              | IAD
#  DEST                | EWR
#  CRS_DEP_TIME        | 1715.0
#  DEP_TIME            | 1705.0
#  DEP_DELAY           | -10.0
#  TAXI_OUT            | 24.0
#  WHEELS_OFF          | 1729.0
#  WHEELS_ON           | 1809.0
#  TAXI_IN             | 13.0
#  CRS_ARR_TIME        | 1900.0
#  ARR_TIME            | 1822.0
#  ARR_DELAY           | -38.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 105.0
#  ACTUAL_ELAPSED_TIME | 77.0
#  AIR_TIME            | 40.0
#  DISTANCE            | 213.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 5-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1212
#  ORIGIN              | ATL
#  DEST                | EWR
#  CRS_DEP_TIME        | 1915.0
#  DEP_TIME            | 1913.0
#  DEP_DELAY           | -2.0
#  TAXI_OUT            | 19.0
#  WHEELS_OFF          | 1932.0
#  WHEELS_ON           | 2108.0
#  TAXI_IN             | 15.0
#  CRS_ARR_TIME        | 2142.0
#  ARR_TIME            | 2123.0
#  ARR_DELAY           | -19.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 147.0
#  ACTUAL_ELAPSED_TIME | 130.0
#  AIR_TIME            | 96.0
#  DISTANCE            | 745.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 6-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1212
#  ORIGIN              | CLE
#  DEST                | ATL
#  CRS_DEP_TIME        | 1645.0
#  DEP_TIME            | 1637.0
#  DEP_DELAY           | -8.0
#  TAXI_OUT            | 12.0
#  WHEELS_OFF          | 1649.0
#  WHEELS_ON           | 1820.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 1842.0
#  ARR_TIME            | 1825.0
#  ARR_DELAY           | -17.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 117.0
#  ACTUAL_ELAPSED_TIME | 108.0
#  AIR_TIME            | 91.0
#  DISTANCE            | 554.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 7-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1214
#  ORIGIN              | DCA
#  DEST                | EWR
#  CRS_DEP_TIME        | 1915.0
#  DEP_TIME            | 1908.0
#  DEP_DELAY           | -7.0
#  TAXI_OUT            | 9.0
#  WHEELS_OFF          | 1917.0
#  WHEELS_ON           | 1953.0
#  TAXI_IN             | 34.0
#  CRS_ARR_TIME        | 2035.0
#  ARR_TIME            | 2027.0
#  ARR_DELAY           | -8.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 80.0
#  ACTUAL_ELAPSED_TIME | 79.0
#  AIR_TIME            | 36.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 8-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1215
#  ORIGIN              | EWR
#  DEST                | DCA
#  CRS_DEP_TIME        | 1715.0
#  DEP_TIME            | 1710.0
#  DEP_DELAY           | -5.0
#  TAXI_OUT            | 28.0
#  WHEELS_OFF          | 1738.0
#  WHEELS_ON           | 1819.0
#  TAXI_IN             | 4.0
#  CRS_ARR_TIME        | 1838.0
#  ARR_TIME            | 1823.0
#  ARR_DELAY           | -15.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 83.0
#  ACTUAL_ELAPSED_TIME | 73.0
#  AIR_TIME            | 41.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 9-------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1217
#  ORIGIN              | EWR
#  DEST                | DCA
#  CRS_DEP_TIME        | 1300.0
#  DEP_TIME            | 1255.0
#  DEP_DELAY           | -5.0
#  TAXI_OUT            | 15.0
#  WHEELS_OFF          | 1310.0
#  WHEELS_ON           | 1349.0
#  TAXI_IN             | 7.0
#  CRS_ARR_TIME        | 1408.0
#  ARR_TIME            | 1356.0
#  ARR_DELAY           | -12.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 68.0
#  ACTUAL_ELAPSED_TIME | 61.0
#  AIR_TIME            | 39.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 10------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1218
#  ORIGIN              | DCA
#  DEST                | EWR
#  CRS_DEP_TIME        | 1500.0
#  DEP_TIME            | 1457.0
#  DEP_DELAY           | -3.0
#  TAXI_OUT            | 14.0
#  WHEELS_OFF          | 1511.0
#  WHEELS_ON           | 1552.0
#  TAXI_IN             | 7.0
#  CRS_ARR_TIME        | 1620.0
#  ARR_TIME            | 1559.0
#  ARR_DELAY           | -21.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 80.0
#  ACTUAL_ELAPSED_TIME | 62.0
#  AIR_TIME            | 41.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 11------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1219
#  ORIGIN              | EWR
#  DEST                | DCA
#  CRS_DEP_TIME        | 2135.0
#  DEP_TIME            | 2131.0
#  DEP_DELAY           | -4.0
#  TAXI_OUT            | 21.0
#  WHEELS_OFF          | 2152.0
#  WHEELS_ON           | 2232.0
#  TAXI_IN             | 3.0
#  CRS_ARR_TIME        | 2252.0
#  ARR_TIME            | 2235.0
#  ARR_DELAY           | -17.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 77.0
#  ACTUAL_ELAPSED_TIME | 64.0
#  AIR_TIME            | 40.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 12------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1220
#  ORIGIN              | CLE
#  DEST                | DCA
#  CRS_DEP_TIME        | 1905.0
#  DEP_TIME            | 1855.0
#  DEP_DELAY           | -10.0
#  TAXI_OUT            | 10.0
#  WHEELS_OFF          | 1905.0
#  WHEELS_ON           | 1956.0
#  TAXI_IN             | 5.0
#  CRS_ARR_TIME        | 2025.0
#  ARR_TIME            | 2001.0
#  ARR_DELAY           | -24.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 80.0
#  ACTUAL_ELAPSED_TIME | 66.0
#  AIR_TIME            | 51.0
#  DISTANCE            | 310.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 13------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1220
#  ORIGIN              | DCA
#  DEST                | EWR
#  CRS_DEP_TIME        | 2100.0
#  DEP_TIME            | 2049.0
#  DEP_DELAY           | -11.0
#  TAXI_OUT            | 10.0
#  WHEELS_OFF          | 2059.0
#  WHEELS_ON           | 2133.0
#  TAXI_IN             | 10.0
#  CRS_ARR_TIME        | 2217.0
#  ARR_TIME            | 2143.0
#  ARR_DELAY           | -34.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 77.0
#  ACTUAL_ELAPSED_TIME | 54.0
#  AIR_TIME            | 34.0
#  DISTANCE            | 199.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 14------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1232
#  ORIGIN              | ORD
#  DEST                | EWR
#  CRS_DEP_TIME        | 905.0
#  DEP_TIME            | 900.0
#  DEP_DELAY           | -5.0
#  TAXI_OUT            | 16.0
#  WHEELS_OFF          | 916.0
#  WHEELS_ON           | 1144.0
#  TAXI_IN             | 6.0
#  CRS_ARR_TIME        | 1212.0
#  ARR_TIME            | 1150.0
#  ARR_DELAY           | -22.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 127.0
#  ACTUAL_ELAPSED_TIME | 110.0
#  AIR_TIME            | 88.0
#  DISTANCE            | 719.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 15------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1233
#  ORIGIN              | EWR
#  DEST                | ORD
#  CRS_DEP_TIME        | 1000.0
#  DEP_TIME            | 1035.0
#  DEP_DELAY           | 35.0
#  TAXI_OUT            | 14.0
#  WHEELS_OFF          | 1049.0
#  WHEELS_ON           | 1156.0
#  TAXI_IN             | 10.0
#  CRS_ARR_TIME        | 1139.0
#  ARR_TIME            | 1206.0
#  ARR_DELAY           | 27.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 159.0
#  ACTUAL_ELAPSED_TIME | 151.0
#  AIR_TIME            | 127.0
#  DISTANCE            | 719.0
#  CARRIER_DELAY       | 0.0
#  WEATHER_DELAY       | 27.0
#  NAS_DELAY           | 0.0
#  SECURITY_DELAY      | 0.0
#  LATE_AIRCRAFT_DELAY | 0.0
#  Unnamed: 27         | NULL
# -RECORD 16------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1234
#  ORIGIN              | ORD
#  DEST                | EWR
#  CRS_DEP_TIME        | 1230.0
#  DEP_TIME            | 1234.0
#  DEP_DELAY           | 4.0
#  TAXI_OUT            | 8.0
#  WHEELS_OFF          | 1242.0
#  WHEELS_ON           | 1511.0
#  TAXI_IN             | 14.0
#  CRS_ARR_TIME        | 1559.0
#  ARR_TIME            | 1525.0
#  ARR_DELAY           | -34.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 149.0
#  ACTUAL_ELAPSED_TIME | 111.0
#  AIR_TIME            | 89.0
#  DISTANCE            | 719.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 17------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1235
#  ORIGIN              | EWR
#  DEST                | ORD
#  CRS_DEP_TIME        | 1343.0
#  DEP_TIME            | 1406.0
#  DEP_DELAY           | 23.0
#  TAXI_OUT            | 13.0
#  WHEELS_OFF          | 1419.0
#  WHEELS_ON           | 1523.0
#  TAXI_IN             | 7.0
#  CRS_ARR_TIME        | 1523.0
#  ARR_TIME            | 1530.0
#  ARR_DELAY           | 7.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 160.0
#  ACTUAL_ELAPSED_TIME | 144.0
#  AIR_TIME            | 124.0
#  DISTANCE            | 719.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 18------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1236
#  ORIGIN              | ORD
#  DEST                | EWR
#  CRS_DEP_TIME        | 1630.0
#  DEP_TIME            | 1619.0
#  DEP_DELAY           | -11.0
#  TAXI_OUT            | 19.0
#  WHEELS_OFF          | 1638.0
#  WHEELS_ON           | 1906.0
#  TAXI_IN             | 35.0
#  CRS_ARR_TIME        | 2002.0
#  ARR_TIME            | 1941.0
#  ARR_DELAY           | -21.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 152.0
#  ACTUAL_ELAPSED_TIME | 142.0
#  AIR_TIME            | 88.0
#  DISTANCE            | 719.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# -RECORD 19------------------------
#  FL_DATE             | 2009-01-01
#  OP_CARRIER          | XE
#  OP_CARRIER_FL_NUM   | 1237
#  ORIGIN              | EWR
#  DEST                | ORD
#  CRS_DEP_TIME        | 1930.0
#  DEP_TIME            | 1927.0
#  DEP_DELAY           | -3.0
#  TAXI_OUT            | 16.0
#  WHEELS_OFF          | 1943.0
#  WHEELS_ON           | 2049.0
#  TAXI_IN             | 8.0
#  CRS_ARR_TIME        | 2123.0
#  ARR_TIME            | 2057.0
#  ARR_DELAY           | -26.0
#  CANCELLED           | 0.0
#  CANCELLATION_CODE   | NULL
#  DIVERTED            | 0.0
#  CRS_ELAPSED_TIME    | 173.0
#  ACTUAL_ELAPSED_TIME | 150.0
#  AIR_TIME            | 126.0
#  DISTANCE            | 719.0
#  CARRIER_DELAY       | NULL
#  WEATHER_DELAY       | NULL
#  NAS_DELAY           | NULL
#  SECURITY_DELAY      | NULL
#  LATE_AIRCRAFT_DELAY | NULL
#  Unnamed: 27         | NULL
# only showing top 20 rows

# %% [markdown]
# #### Dropping Unnecesary Columns

# %%
#Removing the unnecessary columns
cols = ('CANCELLATION_CODE', 'DIVERTED', 'CARRIER_DELAY', 'WEATHER_DELAY',
                                          'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
                                          'Unnamed: 27')

#Storing the new data into dataframe
df=df.drop(*cols)

# %% [markdown]
# #### Dropping Null Values

# %%
#Dropping the null values
df= df.dropna()

# %%
#To check the number of null values
from pyspark.sql.functions import col, isnan, unix_timestamp, when, count

uniondf2 = df.select([
    count(when(
        col(c).contains('None') | col(c).contains('NULL') | (col(c) == 'NA') | col(c).isNull() | isnan(c),
        c)
    ).alias(c) if c != 'FL_DATE' else
    count(when(
        col(c).contains('None') | col(c).contains('NULL') | (col(c) == 'NA') | col(c).isNull() | isnan(unix_timestamp(c)),
        c)
    ).alias(c)
    for c in df.columns
])

uniondf2.show(vertical=True)
# Out:
# -RECORD 0------------------
#  FL_DATE             | 0
#  OP_CARRIER          | 0
#  OP_CARRIER_FL_NUM   | 0
#  ORIGIN              | 0
#  DEST                | 0
#  CRS_DEP_TIME        | 0
#  DEP_TIME            | 0
#  DEP_DELAY           | 0
#  TAXI_OUT            | 0
#  WHEELS_OFF          | 0
#  WHEELS_ON           | 0
#  TAXI_IN             | 0
#  CRS_ARR_TIME        | 0
#  ARR_TIME            | 0
#  ARR_DELAY           | 0
#  CANCELLED           | 0
#  CRS_ELAPSED_TIME    | 0
#  ACTUAL_ELAPSED_TIME | 0
#  AIR_TIME            | 0
#  DISTANCE            | 0
